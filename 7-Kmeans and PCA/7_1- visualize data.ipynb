# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat
import seaborn as sns

# %%
path1 = r"G:\AI学习资料\MachineLearningExercise\machine-learning-ex7\ex7\ex7data1.mat"
row_data1 = loadmat(path1)

# %% [markdown]
# ### plot data1

# %%
X = row_data1["X"]
fig, ax = plt.subplots(figsize=(4,4))
ax.scatter(X[:,0], X[:,1])
plt.show()

# %% [markdown]
# ### plot data2

# %%
path2 = r"G:\AI学习资料\MachineLearningExercise\machine-learning-ex7\ex7\ex7data2.mat"
raw_data2 = loadmat(path2)

df = pd.DataFrame(raw_data2.get("X"),columns=("X1", "X2"))
sns.set(context="notebook", style='dark')
sns.lmplot(x='X1', y='X2', data=df, fit_reg=False)
